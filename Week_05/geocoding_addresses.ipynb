# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Get current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_05

# %% [markdown]
# ## Geocoding a single address

# %% [markdown]
# ### Define base url for address search

# %%
# Define base url for address search
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?" # api endpoint for address search

# Set up search parameters: address, origins and type
parameters = {"searchText": "Hohbergstrasse 1, 8207 Schaffhausen",
              "origins": "address",
              "type": "locations",
             }

# Urllib.parse.urlencode turns parameters into url
print(f"{base_url}{urllib.parse.urlencode(parameters)}") # url encode parameters

# Alles nach ? sind die Parameter (im output unten)
# Out:
# https://api3.geo.admin.ch/rest/services/api/SearchServer?searchText=Hohbergstrasse+1%2C+8207+Schaffhausen&origins=address&type=locations

# %% [markdown]
# ### Server request & response

# %%
# Server request
r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

# Get data in json-format
data = json.loads(r.content) 
print(data)

# Take only the first server response, convert to data frame with relevant infos
df = pd.DataFrame.from_dict(list(data.values())[0][0], orient='columns') 
df.iloc[[1,4,5,6,11,12],:1] # Spalte auswählen nach Index
# Out:
# {'results': [{'attrs': {'detail': 'hohbergstrasse 1 8207 schaffhausen 2939 schaffhausen ch sh', 'featureId': '1613122_0', 'geom_quadindex': '012230222120220010222', 'geom_st_box2d': 'BOX(690945.1641819591 286226.89578480757,690945.1641819591 286226.89578480757)', 'label': 'Hohbergstrasse 1 <b>8207 Schaffhausen</b>', 'lat': 47.72031784057617, 'lon': 8.650716781616211, 'num': 1, 'objectclass': '', 'origin': 'address', 'rank': 7, 'x': 286226.90625, 'y': 690945.1875, 'zoomlevel': 10}, 'id': 930293, 'weight': 1}, {'attrs': {'detail': 'hohbergstrasse 1.1 8207 schaffhausen 2939 schaffhausen ch sh', 'featureId': '191752437_0', 'geom_quadindex': '012230222120221331130', 'geom_st_box2d': 'BOX(690995.6711434489 286207.3170415752,690995.6711434489 286207.3170415752)', 'label': 'Hohbergstrasse 1.1 <b>8207 Schaffhausen</b>', 'lat': 47.72013473510742, 'lon': 8.651385307312012, 'num': 11, 'objectclass': '', 'origin': 'address', 'rank': 7, 'x': 286207.3125, 'y': 690995.6875, 'zoomlevel': 10}, 'id': 2144897, 'weight': 7}, {'attrs': {'detail': 'hohbergstrasse 42.1 8207 schaffhausen 2939 schaffhausen ch sh', 'featureId': '192060601_0', 'geom_quadindex': '012230222031302012132', 'geom_st_box2d': 'BOX(690830.8412850099 286254.3322744127,690830.8412850099 286254.3322744127)', 'label': 'Hohbergstrasse 42.1 <b>8207 Schaffhausen</b>', 'lat': 47.7205810546875, 'lon': 8.649198532104492, 'num': 421, 'objectclass': '', 'origin': 'address', 'rank': 7, 'x': 286254.34375, 'y': 690830.8125, 'zoomlevel': 10}, 'id': 3211057, 'weight': 4}]}
#                                                attrs
# featureId                                  1613122_0
# label      Hohbergstrasse 1 <b>8207 Schaffhausen</b>
# lat                                        47.720318
# lon                                         8.650717
# x                                       286226.90625
# y                                        690945.1875

# %% [markdown]
# ## Geocoding multiple addresses

# %% [markdown]
# ### Importing apartment data

# %%
# Get current working directory
print(os.getcwd())

# Show all files in the directory
flist = fnmatch.filter(os.listdir('.'), '*.csv')
for i in flist:
    print(i)

# Read the data to a pandas data frame
df = pd.read_csv('apartments_data_prepared.csv', 
                 sep=',', 
                 encoding='utf-8')[['web-scraper-order', 
                                    'address_raw', 
                                    'datetime',
                                    'rooms', 
                                    'area', 
                                    'luxurious',
                                    'price_per_m2']]
                                    # [:100] wenn man first 100 apartment adresses will

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(10)
# Out:
# /workspaces/data_analytics/Week_05
# supermarkets_data_prepared.csv
# apartments_data_prepared.csv
# (865, 7)
#   web-scraper-order                             address_raw  \
# 0      1693998201-1       Neuhusstrasse 6, 8630 Rüti ZH, ZH
# 1      1693998201-2      Zürcherstrasse 1, 8173 Neerach, ZH
# 2      1693998201-4     Cramerstrasse 8-12, 8004 Zürich, ZH
# 3      1693998201-5       Rotachstrasse 33, 8003 Zürich, ZH
# 4     1693998201-16         Wolframplatz 1, 8045 Zürich, ZH
# 5     1693998205-25    Badenerstrasse 67, 8953 Dietikon, ZH
# 6     1693998205-26   Frowiesstrasse 36, 8344 Bäretswil, ZH
# 7     1693998205-27  Kanzleistrasse 15, 8418 Schlatt ZH, ZH
# 8     1693998205-29           Bolletweg 14, 8934 Knonau, ZH
# 9     1693998205-30            Im Zauner 24, 8352 Elsau, ZH
#
#               datetime  rooms   area  luxurious  price_per_m2
# 0  2023-09-06 15:10:34    3.0   49.0          0         29.41
# 1  2023-09-06 15:10:34    3.5   65.0          0         28.46
# 2  2023-09-06 15:10:34    2.0   54.0          0         89.87
# 3  2023-09-06 15:10:34    2.0   49.0          0         88.47
# 4  2023-09-06 15:10:34    2.0   32.0          0        109.84
# 5  2023-09-06 15:10:34    3.5  105.0          0         30.48
# 6  2023-09-06 15:10:34    5.5  140.0          0         19.64
# 7  2023-09-06 15:10:34    4.5  104.0          0         25.96
# 8  2023-09-06 15:10:34    5.5  150.0          0         22.60
# 9  2023-09-06 15:10:34    3.0   70.0          0         35.00

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['address_raw'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['address_raw']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['address_raw'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
df.head(5)
# Out:
#   web-scraper-order                          address_raw             datetime  \
# 0      1693998201-1    Neuhusstrasse 6, 8630 Rüti ZH, ZH  2023-09-06 15:10:34
# 1      1693998201-2   Zürcherstrasse 1, 8173 Neerach, ZH  2023-09-06 15:10:34
# 2      1693998201-4  Cramerstrasse 8-12, 8004 Zürich, ZH  2023-09-06 15:10:34
# 3      1693998201-5    Rotachstrasse 33, 8003 Zürich, ZH  2023-09-06 15:10:34
# 4     1693998201-16      Wolframplatz 1, 8045 Zürich, ZH  2023-09-06 15:10:34
#
#    rooms  area  luxurious  price_per_m2        lat       lon
# 0    3.0  49.0          0         29.41  47.252167  8.845798
# 1    3.5  65.0          0         28.46  47.513332  8.474851
# 2    2.0  54.0          0         89.87        NaN       NaN
# 3    2.0  49.0          0         88.47  47.370792  8.514748
# 4    2.0  32.0          0        109.84  47.362282  8.522193

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['address_raw']).add_to(m) # Popup mit Adresse hinzufügen

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7616114f0e863427152aeb0bdf49244 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7616114f0e863427152aeb0bdf49244&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7616114f0e863427152aeb0bdf49244 = L.map(
#                 &quot;map_a7616114f0e863427152aeb0bdf49244&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74e8811f9dee5e6e75119bd8900a008b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_74e8811f9dee5e6e75119bd8900a008b.addTo(map_a7616114f0e863427152aeb0bdf49244);
#
#
#             var marker_1d3b6ad93cac672ae923df025db3e665 = L.marker(
#                 [47.252166748046875, 8.845797538757324],
#                 {}
#             ).addTo(map_a7616114f0e863427152aeb0bdf49244);
#
#
#         var popup_b24f10c76b29e298f6f26869b4b655db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79b9e2507438362e88a744cd4d8ecbb0 = $(`&lt;div id=&quot;html_79b9e2507438362e88a744cd4d8ecbb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Neuhusstrasse 6, 8630 Rüti ZH, ZH&lt;/div&gt;`)[0];
#                 popup_b24f10c76b29e298f6f26869b4b655db.setContent(html_79b9e2507438362e88a744cd4d8ecbb0);
#
#
#
#         marker_1d3b6ad93cac672ae923df025db3e665.bindPopup(popup_b24f10c76b29e298f6f26869b4b655db)
#         ;
#
#
#
#
#             var marker_d522027b1781d92e526a3c9f7259dd45 = L.marker(
#                 [47.51333236694336, 8.47485065460205],
#                 {}
#             ).addTo(map_a7616114f0e863427152aeb0bdf49244);
#
#
#         var popup_fd8fbab72b89308a011960f5eb429b17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_623c6a636152182c0497f8f0102df2a7 = $(`&lt;div id=&quot;html_623c6a636152182c0497f8f0102df2a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zürcherstrasse 1, 8173 Neerach, ZH&lt;/div&gt;`)[0];
#                 popup_fd8fbab72b89308a011960f5eb429b17.setContent(html_623c6a636152182c0497f8f0102df2a7);
#
#
#
#         marker_d522027b1781d92e526a3c9f7259dd45.bindPopup(popup_fd8fbab72b89308a011960f5eb429b17)
#         ;
#
#
#
#
#             var marker_5bea9d8fb9450f68725902d7d0e727f1 = L.marker(
#                 [47.370792388916016, 8.514747619628906],
#                 {}
#             ).addTo(map_a7616114f0e863427152aeb0bdf49244);
#
#
#         var popup_c53b769706a1f1b34dac3ed5c189fa48 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17c40b75c5d3aa98cc65f6cb1ac342f5 = $(`&lt;div id=&quot;html_17c40b75c5d3aa98cc65f6cb1ac342f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rotachstrasse 33, 8003 Zürich, ZH&lt;/div&gt;`)[0];
#                 popup_c53b769706a1f1b34dac3ed5c189fa48.setContent(html_17c40b75c5d3aa98cc65f6cb1ac342f5);
#
#
#
#         marker_5bea9d8fb9450f68725902d7d0e727f1.bindPopup(popup_c53b769706a1f1b34dac3ed5c189fa48)
#         ;
#
#
#
#
#             var marker_be8377163aef595fa074556a58101da5 = L.marker(
#                 [47.362281799316406, 8.52219295501709],
#                 {}
#             ).addTo(map_a7616114f0e863427152aeb0bdf49244);
#
#
#         var popup_9f8eb82ee0f635c5d6a58da009c5e30a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a84988232e33bd6a6da0f2751317f006 = $(`&lt;div id=&quot;html_a84988232e33bd6a6da0f2751317f006&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wolframplatz 1, 8045 Zürich, ZH&lt;/div&gt;`)[0];
#                 popup_9f8eb82ee0f635c5d6a58da009c5e30a.setContent(html_a84988232e33bd6a6da0f2751317f006);
#
#
#
#         marker_be8377163aef595fa074556a58101da5.bindPopup(popup_9f8eb82ee0f635c5d6a58da009c5e30a)
#         ;
#
#
#
#
#             var marker_fde69402dd06e7494c371d1325a41bcf = L.marker(
#                 [47.40792465209961, 8.392560958862305],
#                 {}
#             ).addTo(map_a7616114f0e863427152aeb0bdf49244);
#
#
#         var popup_334f77bbcd35c504c000fd6e19fe5a7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00d885575b033e9fdd7d8528fc4f08a1 = $(`&lt;div id=&quot;html_00d885575b033e9fdd7d8528fc4f08a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Badenerstrasse 67, 8953 Dietikon, ZH&lt;/div&gt;`)[0];
#                 popup_334f77bbcd35c504c000fd6e19fe5a7b.setContent(html_00d885575b033e9fdd7d8528fc4f08a1);
#
#
#
#         marker_fde69402dd06e7494c371d1325a41bcf.bindPopup(popup_334f77bbcd35c504c000fd6e19fe5a7b)
#         ;

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('Geodata/apartments_data_geocoded_all.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-10-19 09:22:25
# Python Version: 3.11.10
# -----------------------------------
