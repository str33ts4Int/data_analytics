# %% [markdown]
# # Stock market analysis using data from the Yahoo-Finance Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

# Install additional library yfinance
import yfinance as yf


# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/WTYK/LC_04

# %% [markdown]
# ## 1.) Get data for the stock TSLA (Tesla) from Yahoo Finance

# %%
# Get current date from datetime in the format YYYY-MM-DD
today = datetime.today().strftime('%Y-%m-%d')
today


# Retrieve the TESLA stock data from Yahoo finance using yf.download
df = yf.download('TSLA', start='2022-01-01', end=today)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
# ...                ...         ...         ...         ...         ...
# 2024-10-01  262.670013  263.980011  248.529999  258.019989  258.019989
# 2024-10-02  247.550003  251.160004  241.500000  249.020004  249.020004
# 2024-10-03  244.479996  249.789993  237.809998  240.660004  240.660004
# 2024-10-04  246.690002  250.960007  244.580002  250.080002  250.080002
# 2024-10-07  249.000000  249.830002  240.699997  240.830002  240.830002
#
#                Volume
# Date
# 2022-01-03  103931400
# 2022-01-04  100248300
# 2022-01-05   80119800
# 2022-01-06   90336600
# 2022-01-07   84164700
# ...               ...
# 2024-10-01   87397600
# 2024-10-02   93983900
# 2024-10-03   80729200
# 2024-10-04   86573200
# 2024-10-07   67856800
#
# [694 rows x 6 columns]

# %% [markdown]
# ## 2.) Apply non-graphical Exploratory Data Analysis (EDA) methods

# %% [markdown]
# ### a) What are the values for min, max. mean and median of the close price?

# %%
# Describe the dataframe
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  694.000000  694.000000  694.000000  694.000000  694.000000
# mean   229.575164  234.704981  224.087329  229.347584  229.347584
# std     52.958394   54.037097   51.389236   52.545857   52.545857
# min    103.000000  111.750000  101.809998  108.099998  108.099998
# 25%    186.539993  190.962498  182.560001  187.102493  187.102493
# 50%    226.595001  232.540001  222.070000  227.680000  227.680000
# 75%    260.600006  267.162498  255.237503  260.937508  260.937508
# max    396.516663  402.666656  378.679993  399.926666  399.926666
#
#              Volume
# count  6.940000e+02
# mean   1.074355e+08
# std    3.934832e+07
# min    4.186470e+07
# 25%    7.902552e+07
# 50%    1.005878e+08
# 75%    1.264340e+08
# max    3.065906e+08

# %% [markdown]
# ### b) What is the 10% Quantile and 90% quantile of close price?

# %%
# Calculate quantiles for the dataframe (10%, Median, 90%)
df.quantile([0.1, 0.5, 0.9])
# Out:
#            Open        High         Low       Close   Adj Close       Volume
# 0.1  170.121007  174.566000  167.202000  170.896002  170.896002   64053450.0
# 0.5  226.595001  232.540001  222.070000  227.680000  227.680000  100587800.0
# 0.9  300.531000  307.316660  292.217334  300.419669  300.419669  161043560.0

# %% [markdown]
# ## 3.) Apply graphical Exploratory Data Analysis (EDA) methods

# %% [markdown]
# ### a) Create a line chart of the close price

# %%
# Create a line chart of the close price
plt.figure(figsize=(12, 6))
sns.lineplot(data=df['Close'], label='Close Price')
plt.title('TESLA Stock Price')
plt.xlabel('Date')
plt.ylabel('Closed Price')
plt.legend(['Close Price'])
plt.grid()
plt.show()

# Set the title and axis labels


# Add a legend to the axis


# Add grid


# Show the plot

# %% [markdown]
# ### b) Create a histogram of the close price

# %%
# Create a histogram of the close price
plt.figure(figsize=(12, 6))
sns.histplot(df['Close'], bins=30, kde=True, color='#becc41') #Seaborn for histogram
plt.title('TESLA Stock Price')
plt.xlabel('Closed Price')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# ### c) Create a boxplot of the close price

# %%
# Create a boxplot of the close price
plt.figure(figsize=(9, 1.1))
sns.boxplot(x=df['Close'], color='#becc41')
plt.title('TESLA Close Price Distribution')
plt.xlabel('Closed Price')
plt.grid()
plt.show()


# Show the plot

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-10-08 07:15:06
# Python Version: 3.11.10
# -----------------------------------
